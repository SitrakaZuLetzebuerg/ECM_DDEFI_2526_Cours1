# %% [markdown]
# <a href="https://colab.research.google.com/github/SitrakaZuLetzebuerg/ECM_DDEFI_2526_Cours1/blob/main/Cours_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Première fonction de Python
print("Hello Centrale MARSEILLE")
# Out:
# Hello Centrale MARSEILLE

# %%
# Variables
a = "Alice" #data type is STRING
height = 1.85 #data type is FLOAT
argent = 10000 #data is INTEGER
is_student = True #Bolean

# %%
height
print(height)
# Out:
# 1.85

# %%
# Il existe depuis la maj un F PRINT

print (f"{a} fait {height} en m, et est une etudiante {is_student}")
# Out:
# Alice fait 1.85 en m, et est une etudiante True

# %%
print("mnt on MERGE")

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
import pandas as pd # Pour manipuler des DATA FRAMES
import numpy as np #pour les maths de matrices
import matplotlib #pour faire des plots

# %%
# We take a sub part of the lib to make it faster !
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
np.random.seed(0) #CREATION DE VARIABLES RANDOMS
#faisons un exemple de finance
dates = pd.date_range(start='2020-01-01', periods =24, freq='M')
# Out:
# /tmp/ipython-input-2898583753.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(start='2020-01-01', periods =24, freq='M')

# %%
luxalpha_equity = np.random.normal(0.005, 0.02, 24)
grand_duchy_bond = np.random.normal(0.004, 0.015, 24)
luxinvest_growth = np.random.normal(0.006, 0.03, 24)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Génération de données fictives
np.random.seed(0)  # Pour la reproductibilité
dates = pd.date_range(start='2020-01-01', periods=24, freq='M')
fonds_a = np.random.normal(0.005, 0.02, 24)
fonds_b = np.random.normal(0.004, 0.015, 24)
fonds_c = np.random.normal(0.006, 0.03, 24)

# Création du DataFrame s'appelant Data
data = pd.DataFrame({
    'Date': dates,
    'Fonds_A': fonds_a,
    'Fonds_B': fonds_b,
    'Fonds_C': fonds_c
})

# Sauvegarde des données dans un fichier CSV
data.to_csv('rendements_fonds.csv', index=False)

# Affichage des premières lignes du DataFrame
print(data.head())
# Out:
#         Date   Fonds_A   Fonds_B   Fonds_C
# 0 2020-01-31  0.040281  0.038046 -0.042417
# 1 2020-02-29  0.013003 -0.017815 -0.000382
# 2 2020-03-31  0.024575  0.004686 -0.020864
# 3 2020-04-30  0.049818  0.001192  0.017607
# 4 2020-05-31  0.042351  0.026992 -0.009324
# /tmp/ipython-input-135299015.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(start='2020-01-01', periods=24, freq='M')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Génération de données fictives
np.random.seed(0)  # Pour la reproductibilité
dates = pd.date_range(start='2020-01-01', periods=24, freq='M')
luxalpha_equity = np.random.normal(0.005, 0.02, 24)
grand_duchy_bond = np.random.normal(0.004, 0.015, 24)
luxinvest_growth = np.random.normal(0.006, 0.03, 24)

# Création du DataFrame
data = pd.DataFrame({
    'Date': dates,
    'LuxAlpha European Equity Fund': luxalpha_equity,
    'Grand Duchy Bond Fund': grand_duchy_bond,
    'LuxInvest Global Growth Fund': luxinvest_growth
})

# Sauvegarde des données dans un fichier CSV
data.to_csv('rendements_fonds_luxembourgeois.csv', index=False)

# Affichage des premières lignes du DataFrame
print(data.head())

# Chargement des données
data = pd.read_csv('rendements_fonds_luxembourgeois.csv')

# Calcul du rendement moyen mensuel de chaque fonds
rendement_moyen = data[['LuxAlpha European Equity Fund', 'Grand Duchy Bond Fund', 'LuxInvest Global Growth Fund']].mean()
print("Rendement moyen mensuel de chaque fonds :")
print(rendement_moyen)

# Comparaison des rendements des fonds
meilleur_fonds = rendement_moyen.idxmax()
print(f"Le fonds avec la meilleure performance est : {meilleur_fonds}")

# Visualisation des rendements mensuels des fonds
plt.figure(figsize=(10, 6))
for fonds in ['LuxAlpha European Equity Fund', 'Grand Duchy Bond Fund', 'LuxInvest Global Growth Fund']:
    plt.plot(data['Date'], data[fonds], label=fonds)

plt.xlabel('Date')
plt.ylabel('Rendement Mensuel')
plt.title('Rendements Mensuels des Fonds Luxembourgeois')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-2478996719.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(start='2020-01-01', periods=24, freq='M')
#         Date  LuxAlpha European Equity Fund  Grand Duchy Bond Fund  \
# 0 2020-01-31                       0.040281               0.038046
# 1 2020-02-29                       0.013003              -0.017815
# 2 2020-03-31                       0.024575               0.004686
# 3 2020-04-30                       0.049818               0.001192
# 4 2020-05-31                       0.042351               0.026992
#
#    LuxInvest Global Growth Fund
# 0                     -0.042417
# 1                     -0.000382
# 2                     -0.020864
# 3                      0.017607
# 4                     -0.009324
# Rendement moyen mensuel de chaque fonds :
# LuxAlpha European Equity Fund    0.013008
# Grand Duchy Bond Fund            0.003528
# ...
